# %%
import pandas as pd

# %%
#import 2015 csv
data = pd.read_csv("../Resources/2015.csv")
data.columns = data.iloc[0]
data = data[1:]
data.head()
# Out:
# C:\Users\Kaiza\AppData\Local\Temp\ipykernel_13320\2390086908.py:2: DtypeWarning: Columns (5,108,121,196,197,198) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("../Resources/2015.csv")
# 0  Country    Age Gender Tabs or Spaces Years IT / Programming Experience  \
# 1  Croatia  25-29   Male           Tabs                       2 - 5 years
# 2   France  20-24   Male         Spaces                       1 - 2 years
# 3    India  20-24   Male           Tabs                       1 - 2 years
# 4   Latvia  25-29   Male     It depends                      6 - 10 years
# 5   Norway  30-34   Male           Tabs                       2 - 5 years
#
# 0              Occupation Desktop Operating System  \
# 1  Back-end web developer                   Ubuntu
# 2  Back-end web developer                Windows 7
# 3  Back-end web developer                Windows 7
# 4  Back-end web developer                   Ubuntu
# 5  Back-end web developer                Windows 8
#
# 0 Desktop Operating System: write-in Current Lang & Tech: Android  \
# 1                                NaN                          NaN
# 2                                NaN                          NaN
# 3                                NaN                          NaN
# 4                                NaN                          NaN
# 5                                NaN                          NaN
#
# 0 Current Lang & Tech: Arduino  ...  \
# 1                          NaN  ...
# 2                          NaN  ...
# 3                          NaN  ...
# 4                          NaN  ...
# 5                          NaN  ...
#
# 0 Why use Stack Overflow: I don't use Stack Overflow  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
# 0 How often are Stack Overflow's answers helpful  \
# 1                                        Usually
# 2                                        Usually
# 3                                         Rarely
# 4                                        Usually
# 5                                        Usually
#
# 0       Why answer: Help a programmer in need  \
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4  It feels good to help a programmer in need
# 5  It feels good to help a programmer in need
#
# 0                Why answer: Help future programmers  \
# 1                                                NaN
# 2  My answer will help lots of people who have th...
# 3                                                NaN
# 4  My answer will help lots of people who have th...
# 5                                                NaN
#
# 0           Why answer: Demonstrate expertise  \
# 1  It feels good to demonstrate my expertise.
# 2  It feels good to demonstrate my expertise.
# 3                                         NaN
# 4  It feels good to demonstrate my expertise.
# 5                                         NaN
#
# 0                  Why answer: Self promotion  \
# 1  Demonstrating my expertise will benefit me
# 2                                         NaN
# 3  Demonstrating my expertise will benefit me
# 4  Demonstrating my expertise will benefit me
# 5  Demonstrating my expertise will benefit me
#
# 0  Why answer: Sense of responsibility to developers Why answer: No idea  \
# 1  I feel a sense of responsibility to the develo...                 NaN
# 2                                                NaN                 NaN
# 3                                                NaN                 NaN
# 4  I feel a sense of responsibility to the develo...                 NaN
# 5                                                NaN                 NaN
#
# 0 Why answer: I don't answer and I don't want to  \
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# 5                                            NaN
#
# 0           Why answer: I don't answer but I want to
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  I don't answer much (or at all), but I want to...
#
# [5 rows x 222 columns]

# %%
data.columns
# Out:
# Index(['Country', 'Age', 'Gender', 'Tabs or Spaces',
#        'Years IT / Programming Experience', 'Occupation',
#        'Desktop Operating System', 'Desktop Operating System: write-in',
#        'Current Lang & Tech: Android', 'Current Lang & Tech: Arduino',
#        ...
#        'Why use Stack Overflow: I don't use Stack Overflow',
#        'How often are Stack Overflow's answers helpful',
#        'Why answer: Help a programmer in need',
#        'Why answer: Help future programmers',
#        'Why answer: Demonstrate expertise', 'Why answer: Self promotion',
#        'Why answer: Sense of responsibility to developers',
#        'Why answer: No idea', 'Why answer: I don't answer and I don't want to',
#        'Why answer: I don't answer but I want to'],
#       dtype='object', name=0, length=222)

# %%
# make df with only the important columns
cleaned = data[['Years IT / Programming Experience','Occupation','Compensation']]
cleaned['Year'] = '2015'
cleaned = cleaned.dropna()
# Out:
# C:\Users\Kaiza\AppData\Local\Temp\ipykernel_13320\3802260907.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned['Year'] = '2015'

# %%
cleaned['Occupation'].value_counts()
# Out:
# Full-stack web developer                                 6027
# Student                                                  2357
# Back-end web developer                                   1840
# Desktop developer                                        1514
# Front-end web developer                                  1041
# Mobile developer - Android                                727
# Mobile developer - iOS                                    550
# Enterprise level services developer                       542
# Embedded application developer                            531
# Developer with a statistics or mathematics background     398
# Data scientist                                            357
# Executive (VP of Eng., CTO, CIO, etc.)                    344
# Mobile developer                                          333
# System administrator                                      299
# DevOps                                                    291
# Business intelligence or data warehousing expert          161
# Quality Assurance                                         146
# Product manager                                           136
# Graphics programmer                                       136
# Designer                                                  120
# Machine learning developer                                115
# Database administrator                                     97
# Growth hacker                                              50
# Mobile developer - Windows Phone                           40
# Name: Occupation, dtype: int64

# %%
# create smaller df with only the jobs we want
analyst = cleaned[cleaned['Occupation'].str.contains('analyst')]
scientist = cleaned[cleaned['Occupation'].str.contains('scientist')]
machine = cleaned[cleaned['Occupation'].str.contains('machine')]
# engineer = cleaned[cleaned['DevType'].str.contains('engineer')]

# %%
# convert job titles to specific
analyst['Occupation'] = 'Data Analyst'
scientist['Occupation'] = 'Data Scientist'
machine['Occupation'] = 'Machine Learning Engineer'
# Out:
# C:\Users\Kaiza\AppData\Local\Temp\ipykernel_13320\3345237813.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scientist['Occupation'] = 'Data Scientist'

# %%
combined = pd.concat([analyst, scientist, machine], ignore_index=True)
combined
# Out:
# 0   Years IT / Programming Experience      Occupation        Compensation  \
# 0                        6 - 10 years  Data Scientist   $20,000 - $40,000
# 1                        6 - 10 years  Data Scientist   $60,000 - $80,000
# 2                        6 - 10 years  Data Scientist   $40,000 - $60,000
# 3                         2 - 5 years  Data Scientist      Rather not say
# 4                           11+ years  Data Scientist  $80,000 - $100,000
# ..                                ...             ...                 ...
# 352                       1 - 2 years  Data Scientist   $20,000 - $40,000
# 353                  Less than 1 year  Data Scientist          Unemployed
# 354                         11+ years  Data Scientist   $20,000 - $40,000
# 355                       2 - 5 years  Data Scientist   $20,000 - $40,000
# 356                       2 - 5 years  Data Scientist   $20,000 - $40,000
#
# 0    Year
# 0    2015
# 1    2015
# 2    2015
# 3    2015
# 4    2015
# ..    ...
# 352  2015
# 353  2015
# 354  2015
# 355  2015
# 356  2015
#
# [357 rows x 4 columns]

# %%
combined.to_csv('../Outputs/2016.csv', index=False)
