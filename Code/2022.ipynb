# %%
import pandas as pd

# %%
#import 2022 csv
data = pd.read_csv("../Resources/2022.csv")
data.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                                      None of these
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                          Fully remote
# 4  Employed, full-time  Hybrid (some remote, some in-person)
#
#                            CodingActivities  \
# 0                                       NaN
# 1  Hobby;Contribute to open-source projects
# 2                                     Hobby
# ...

# %%
data.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'BuyNewTool', 'Country', 'Currency',
#        'CompTotal', 'CompFreq', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysProfessional use',
#        'OpSysPersonal use', 'VersionControlSystem', 'VCInteraction',
#        'VCHostingPersonal use', 'VCHostingProfessional use',
#        'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
# ...

# %%
# make df with only the important columns
cleaned = data[['YearsCodePro','DevType','ConvertedCompYearly','OrgSize']]
cleaned['Year'] = '2022'
cleaned = cleaned.dropna()
# Out:
# C:\Users\Kaiza\AppData\Local\Temp\ipykernel_6664\343298146.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned['Year'] = '2022'

# %%
cleaned['DevType'].value_counts()
# Out:
# Developer, full-stack                                                                                                                                                                                                                                                                             4968
# Developer, back-end                                                                                                                                                                                                                                                                               3806
# Developer, front-end                                                                                                                                                                                                                                                                              1540
# ...

# %%
# create smaller df with only the jobs we want
analyst = cleaned[cleaned['DevType'].str.contains('analyst')]
scientist = cleaned[cleaned['DevType'].str.contains('scientist')]
machine = cleaned[cleaned['DevType'].str.contains('machine')]
# engineer = cleaned[cleaned['DevType'].str.contains('engineer')]

# %%
# convert job titles to specific
analyst['DevType'] = 'Data Analyst'
scientist['DevType'] = 'Data Scientist'
machine['DevType'] = 'Machine Learning Engineer'
# Out:
# C:\Users\Kaiza\AppData\Local\Temp\ipykernel_6664\4197962986.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   analyst['DevType'] = 'Data Analyst'
# C:\Users\Kaiza\AppData\Local\Temp\ipykernel_6664\4197962986.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scientist['DevType'] = 'Data Scientist'
# C:\Users\Kaiza\AppData\Local\Temp\ipykernel_6664\4197962986.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
combined = pd.concat([analyst, scientist, machine], ignore_index=True)
combined
# Out:
#      YearsCodePro                    DevType  ConvertedCompYearly  \
# 0              15               Data Analyst             130000.0
# 1              22               Data Analyst             450000.0
# 2               5               Data Analyst              78084.0
# 3              12               Data Analyst              15480.0
# 4              11               Data Analyst             200000.0
# ...           ...                        ...                  ...
# 5909            4  Machine Learning Engineer             250000.0
# 5910            6  Machine Learning Engineer              51336.0
# 5911            6  Machine Learning Engineer              39000.0
# 5912           16  Machine Learning Engineer              47772.0
# 5913            3  Machine Learning Engineer              75384.0
#
#                        OrgSize  Year
# 0         100 to 499 employees  2022
# 1         100 to 499 employees  2022
# 2     10,000 or more employees  2022
# ...

# %%
combined['OrgSize'].value_counts()
# Out:
# 10,000 or more employees                              1081
# 20 to 99 employees                                    1077
# 100 to 499 employees                                   902
# 1,000 to 4,999 employees                               774
# 2 to 9 employees                                       562
# 10 to 19 employees                                     457
# 500 to 999 employees                                   400
# 5,000 to 9,999 employees                               332
# Just me - I am a freelancer, sole proprietor, etc.     244
# I don’t know                                            85
# Name: OrgSize, dtype: int64

# %%
combined['OrgSize']=combined['OrgSize'].replace(["10,000 or more employees"],["10000+"])
combined['OrgSize']=combined['OrgSize'].replace(["20 to 99 employees"],["10-100"])
combined['OrgSize']=combined['OrgSize'].replace(["100 to 499 employees"],["100-1000"])
combined['OrgSize']=combined['OrgSize'].replace(["1,000 to 4,999 employees"],["1000-4999"])
combined['OrgSize']=combined['OrgSize'].replace(["2 to 9 employees"],["2-9"])
combined['OrgSize']=combined['OrgSize'].replace(["10 to 19 employees"],["10-100"])
combined['OrgSize']=combined['OrgSize'].replace(["500 to 999 employees"],["100-1000"])
combined['OrgSize']=combined['OrgSize'].replace(["5,000 to 9,999 employees"],["5000-9999"])
combined['OrgSize']=combined['OrgSize'].replace(["Just me - I am a freelancer, sole proprietor, etc."],["1"])
combined['OrgSize']=combined['OrgSize'].replace(["I don’t know"],["0"])

combined
# Out:
#      YearsCodePro                    DevType  ConvertedCompYearly    OrgSize  \
# 0              15               Data Analyst             130000.0   100-1000
# 1              22               Data Analyst             450000.0   100-1000
# 2               5               Data Analyst              78084.0     10000+
# 3              12               Data Analyst              15480.0     10000+
# 4              11               Data Analyst             200000.0  1000-4999
# ...           ...                        ...                  ...        ...
# 5909            4  Machine Learning Engineer             250000.0   100-1000
# 5910            6  Machine Learning Engineer              51336.0   100-1000
# 5911            6  Machine Learning Engineer              39000.0     10-100
# 5912           16  Machine Learning Engineer              47772.0        2-9
# 5913            3  Machine Learning Engineer              75384.0     10-100
#
#       Year
# 0     2022
# 1     2022
# ...

# %%
combined.to_csv('../Outputs/2022.csv', index=False)
