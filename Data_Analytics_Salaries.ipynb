# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-48e35af6-e6c2-4de8-b2e7-29c769b7f25d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-48e35af6-e6c2-4de8-b2e7-29c769b7f25d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ds_salaries.csv to ds_salaries (2).csv

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
import io

# Import and read the charity_data.csv.
import pandas as pd 
salaries_df = pd.read_csv(io.BytesIO(uploaded['ds_salaries.csv']))
salaries_df.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           1       2020               SE              FT
# 1           2       2020               EN              FT
# 2           3       2020               SE              FT
# 3           4       2020               MI              FT
# 4           5       2020               MI              FT
#
#                    job_title  salary salary_currency  salary_in_usd  \
# 0  Machine Learning Engineer  150000             USD         150000
# 1               Data Analyst   72000             USD          72000
# 2        Lead Data Scientist  190000             USD         190000
# 3      Business Data Analyst  135000             USD         135000
# 4          Lead Data Analyst   87000             USD          87000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 US            50               US            L
# 1                 US           100               US            L
# ...

# %%
# Replace Abbreviations in columns titled experienc_level and employment_type
salaries_df = salaries_df.replace(['SE','EN','MI','EX','FT','CT','PT','FL'],['Senior-Level','Entry-Level','Mid-Level','Executive-Level','Full-Time','Contractor','Part-Time','Freelance'])

salaries_df.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           1       2020     Senior-Level       Full-Time
# 1           2       2020      Entry-Level       Full-Time
# 2           3       2020     Senior-Level       Full-Time
# 3           4       2020        Mid-Level       Full-Time
# 4           5       2020        Mid-Level       Full-Time
#
#                    job_title  salary salary_currency  salary_in_usd  \
# 0  Machine Learning Engineer  150000             USD         150000
# 1               Data Analyst   72000             USD          72000
# 2        Lead Data Scientist  190000             USD         190000
# 3      Business Data Analyst  135000             USD         135000
# 4          Lead Data Analyst   87000             USD          87000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 US            50               US            L
# 1                 US           100               US            L
# ...

# %%
# Replace numbers in remote_ratio to elaborate on remote status
salaries_df["remote_ratio"] = salaries_df["remote_ratio"].replace([0,50,100],['Not Remote','Hybrid','Remote'])

salaries_df.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           1       2020     Senior-Level       Full-Time
# 1           2       2020      Entry-Level       Full-Time
# 2           3       2020     Senior-Level       Full-Time
# 3           4       2020        Mid-Level       Full-Time
# 4           5       2020        Mid-Level       Full-Time
#
#                    job_title  salary salary_currency  salary_in_usd  \
# 0  Machine Learning Engineer  150000             USD         150000
# 1               Data Analyst   72000             USD          72000
# 2        Lead Data Scientist  190000             USD         190000
# 3      Business Data Analyst  135000             USD         135000
# 4          Lead Data Analyst   87000             USD          87000
#
#   employee_residence remote_ratio company_location company_size
# 0                 US       Hybrid               US            L
# 1                 US       Remote               US            L
# ...

# %%
# Define type of data
salaries_df.dtypes
# Out:
# Unnamed: 0             int64
# work_year              int64
# experience_level      object
# employment_type       object
# job_title             object
# salary                 int64
# salary_currency       object
# salary_in_usd          int64
# employee_residence    object
# remote_ratio          object
# company_location      object
# company_size          object
# dtype: object

# %%
# Count types of Job Titles
salaries_df["job_title"].value_counts()
# Out:
# Data Engineer                               82
# Data Scientist                              78
# Data Analyst                                70
# Machine Learning Engineer                   16
# Data Science Manager                        10
# Data Architect                               9
# Data Analytics Manager                       7
# Machine Learning Scientist                   6
# Analytics Engineer                           4
# Principal Data Scientist                     4
# Principal Data Engineer                      3
# Data Engineering Manager                     3
# Research Scientist                           3
# BI Data Analyst                              3
# Applied Data Scientist                       3
# Head of Data Science                         3
# ML Engineer                                  2
# Financial Data Analyst                       2
# Lead Data Analyst                            2
# Director of Data Science                     2
# ...

# %%
# Rename Job titles to allow for better grouping
salaries_df['job_title']=salaries_df['job_title'].replace(["Data Analytics Lead"],["Data Analyst"])
salaries_df['job_title']=salaries_df['job_title'].replace(["Lead Data Scientist"],["Data Scientist"])
salaries_df['job_title']=salaries_df['job_title'].replace(["Big Data Engineer"],["Data Engineer"])
salaries_df['job_title']=salaries_df['job_title'].replace(["Head of Data"],["Data Engineering Manager"])
salaries_df['job_title']=salaries_df['job_title'].replace(["Data Analytics Engineer"],["Data Engineer"])
salaries_df['job_title']=salaries_df['job_title'].replace(["Lead Data Engineer"],["Data Engineer"])
salaries_df['job_title']=salaries_df['job_title'].replace(["Applied Machine Learning Scientist"],["Machine Learning Scientist"])
salaries_df['job_title']=salaries_df['job_title'].replace(["Data Specialist"],["Data Scientist"])
salaries_df['job_title']=salaries_df['job_title'].replace(["Machine Learning Infrastructure Engineer"],["Machine Learning Engineer"])
salaries_df['job_title']=salaries_df['job_title'].replace(["NLP Engineer"],["Machine Learning Engineer"])
salaries_df['job_title']=salaries_df['job_title'].replace(["Staff Data Scientist "],["Data Scientist"])
salaries_df['job_title']=salaries_df['job_title'].replace(["Lead Data Analyst"],["Data Analyst"])
salaries_df['job_title']=salaries_df['job_title'].replace(["Applied Data Scientist"],["Data Scientist"])
salaries_df['job_title']=salaries_df['job_title'].replace(["BI Data Analyst"],["Data Analyst"])
salaries_df['job_title']=salaries_df['job_title'].replace(["ML Engineer"],["Machine Learning Engineer"])
salaries_df['job_title']=salaries_df['job_title'].replace(["Financial Data Analyst"],["Data Analyst"])
salaries_df['job_title']=salaries_df['job_title'].replace(["Research Scientist"],["Data Scientist"])
salaries_df['job_title']=salaries_df['job_title'].replace(["Applied Data Scientist"],["Data Scientist"])
salaries_df['job_title']=salaries_df['job_title'].replace(["Computer Vision Engineer"],["Machine Learning Engineer"])
salaries_df['job_title']=salaries_df['job_title'].replace(["AI Scientist"],["Machine Learning Engineer"])
salaries_df['job_title']=salaries_df['job_title'].replace(["Staff Data Scientist"],["Data Scientist"])
salaries_df['job_title']=salaries_df['job_title'].replace(["Principal Data Analyst"],["Data Analyst"])
salaries_df['job_title']=salaries_df['job_title'].replace(["Director of Data Engineering"],["Data Engineering Manager"])
salaries_df['job_title']=salaries_df['job_title'].replace(["Computer Vision Software Engineer"],["Machine Learning Engineer"])
salaries_df['job_title']=salaries_df['job_title'].replace(["Business Data Analyst"],["Data Analyst"])
salaries_df['job_title']=salaries_df['job_title'].replace(["Data Science Consultant"],["Data Scientist"])
salaries_df['job_title']=salaries_df['job_title'].replace(["Director of Data Science"],["Data Science Manager"])
salaries_df['job_title']=salaries_df['job_title'].replace(["Head of Data Science"],["Data Science Manager"])

salaries_df["job_title"].value_counts()
# Out:
# Data Scientist                89
# Data Engineer                 85
# Data Analyst                  81
# Machine Learning Engineer     23
# Data Science Manager          15
# Data Architect                 9
# Machine Learning Scientist     7
# Data Analytics Manager         7
# Data Engineering Manager       5
# Principal Data Scientist       4
# Analytics Engineer             4
# Principal Data Engineer        3
# Name: job_title, dtype: int64

# %%
# Rename columns

salaries_df.columns = salaries_df.columns.str.replace('work_year', 'Year')
salaries_df.columns = salaries_df.columns.str.replace('experience_level', 'Experience Level')
salaries_df.columns = salaries_df.columns.str.replace('employment_type', 'Employment Type')
salaries_df.columns = salaries_df.columns.str.replace('job_title', 'Job Title')
salaries_df.columns = salaries_df.columns.str.replace('salary_in_usd', 'Salary($)')
salaries_df.columns = salaries_df.columns.str.replace('employee_residence', 'Employee Residence')
salaries_df.columns = salaries_df.columns.str.replace('remote_ratio', 'Remote Status')
salaries_df.columns = salaries_df.columns.str.replace('company_location', 'Company Location')
salaries_df.columns = salaries_df.columns.str.replace('company_size', 'Company Size')
salaries_df.head()
# Out:
#    Unnamed: 0  Year Experience Level Employment Type  \
# 0           1  2020     Senior-Level       Full-Time
# 1           2  2020      Entry-Level       Full-Time
# 2           3  2020     Senior-Level       Full-Time
# 3           4  2020        Mid-Level       Full-Time
# 4           5  2020        Mid-Level       Full-Time
#
#                    Job Title  salary salary_currency  Salary($)  \
# 0  Machine Learning Engineer  150000             USD     150000
# 1               Data Analyst   72000             USD      72000
# 2             Data Scientist  190000             USD     190000
# 3               Data Analyst  135000             USD     135000
# 4               Data Analyst   87000             USD      87000
#
#   Employee Residence Remote Status Company Location Company Size
# 0                 US        Hybrid               US            L
# 1                 US        Remote               US            L
# ...

# %%
salaries_df = salaries_df.replace(['S','M','L'],['Small','Medium','Large'])

salaries_df.head()
# Out:
#    Unnamed: 0  Year Experience Level Employment Type  \
# 0           1  2020     Senior-Level       Full-Time
# 1           2  2020      Entry-Level       Full-Time
# 2           3  2020     Senior-Level       Full-Time
# 3           4  2020        Mid-Level       Full-Time
# 4           5  2020        Mid-Level       Full-Time
#
#                    Job Title  salary salary_currency  Salary($)  \
# 0  Machine Learning Engineer  150000             USD     150000
# 1               Data Analyst   72000             USD      72000
# 2             Data Scientist  190000             USD     190000
# 3               Data Analyst  135000             USD     135000
# 4               Data Analyst   87000             USD      87000
#
#   Employee Residence Remote Status Company Location Company Size
# 0                 US        Hybrid               US        Large
# 1                 US        Remote               US        Large
# ...

# %%
salaries_df = salaries_df.drop('salary', axis=1)
salaries_df = salaries_df.drop('salary_currency', axis=1)

salaries_df.head()
# Out:
#    Unnamed: 0  Year Experience Level Employment Type  \
# 0           1  2020     Senior-Level       Full-Time
# 1           2  2020      Entry-Level       Full-Time
# 2           3  2020     Senior-Level       Full-Time
# 3           4  2020        Mid-Level       Full-Time
# 4           5  2020        Mid-Level       Full-Time
#
#                    Job Title  Salary($) Employee Residence Remote Status  \
# 0  Machine Learning Engineer     150000                 US        Hybrid
# 1               Data Analyst      72000                 US        Remote
# 2             Data Scientist     190000                 US        Remote
# 3               Data Analyst     135000                 US        Remote
# 4               Data Analyst      87000                 US        Remote
#
#   Company Location Company Size
# 0               US        Large
# 1               US        Large
# 2               US        Small
# 3               US        Large
# 4               US        Large
